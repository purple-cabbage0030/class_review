# %% [markdown]
# 1. 구글 드라이브 root 에 clone
# 1. clone한 workspace를 코드 디렉토리로 옮긴다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# google drive 연결 후
# cd 명령어는 jupyter notebook의 magic command(%로 시작)을 사용
# %cd /content/drive/MyDrive/Colab Notebooks/object_detection_src
# Out:
# /content/drive/MyDrive/Colab Notebooks/object_detection_src

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/object_detection_src

# %%
# !git clone https://github.com/dbgmlek/object_detection_workspace.git
# Out:
# Cloning into 'object_detection_workspace'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 58 (delta 24), reused 46 (delta 15), pack-reused 0
# Unpacking objects: 100% (58/58), done.

# %%
# %ls -al
# Out:
# total 11
# drwx------ 6 root root 4096 Sep 28 01:22 object_detection_workspace/
# -rw------- 1 root root 6708 Sep 28 01:22 tensorflow_object_detection_template_clone.ipynb

# %%
# !ls
# Out:
# object_detection_workspace  tensorflow_object_detection_template_clone.ipynb

# %%
# 폴더명 변경
# !mv object_detection_workspace/  sign_language_letters/

# %%
# !ls -al
# Out:
# total 12
# drwx------ 6 root root 4096 Sep 28 01:22 sign_language_letters
# -rw------- 1 root root 7735 Sep 28 01:33 tensorflow_object_detection_template_clone.ipynb

# %%
# !ls -al sign_language_letters
# Out:
# total 35
# drwx------ 8 root root  4096 Sep 28 01:22 .git
# -rw------- 1 root root    19 Sep 28 01:22 .gitignore
# -rw------- 1 root root 18039 Sep 28 01:22 Process.ipynb
# drwx------ 2 root root  4096 Sep 28 01:22 raw_data
# -rw------- 1 root root    63 Sep 28 01:22 README.md
# drwx------ 2 root root  4096 Sep 28 01:22 scripts
# drwx------ 6 root root  4096 Sep 28 01:22 workspace

# %% [markdown]
# # Dataset download

# %%
import gdown 
url = 'https://drive.google.com/uc?id=1qSkS6DaoSvVtFMlmNRssBNAb5eZRAEnI'
fname = 'american_sign_language_letters.zip'
gdown.download(url, fname, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qSkS6DaoSvVtFMlmNRssBNAb5eZRAEnI
# To: /content/drive/MyDrive/Colab Notebooks/object_detection_src/american_sign_language_letters.zip
# 24.3MB [00:00, 64.1MB/s]
# 'american_sign_language_letters.zip'

# %%
# !mv american_sign_language_letters.zip /content/drive/MyDrive/ColabNotebooks/object_detection_src/sign_language_letters/raw_data
