# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data1 = pd.read_csv('./dataset/aptPriceDataSet/avg15.09.csv', header=[3])
data1
# Out:
#        시도  시군구     12월      1월      2월      3월      4월      5월      6월  \
# 0      전국  NaN   8,059   8,130   8,195   8,204   8,289   8,358   8,344
# 1      서울  NaN  18,189  17,925  17,925  18,016  18,098  19,446  18,867
# 2   6대광역시   부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453
# 3     NaN   대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360
# 4     NaN   인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058
# 5     NaN   광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659
# 6     NaN   대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333
# 7     NaN   울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153
# 8     NaN  NaN   8,151   8,355   8,597   8,552   8,585   8,606   8,669
# 9      경기  NaN  10,855  10,855  10,791  10,784  10,876  10,646  10,266
# 10    수도권  NaN  13,083  12,995  13,041  13,069  12,991  13,312  13,064
# 11     세종  NaN   7,601   7,600   7,532   7,814   7,908   7,934   8,067
# ...

# %%
data1 = data1.drop([1])
data1 = data1.drop([2])
data1
# Out:
#        0    1       2       3       4       5       6       7       8   \
# 3      시도  시군구     12월      1월      2월      3월      4월      5월      6월
# 4      전국  NaN   8,059   8,130   8,195   8,204   8,289   8,358   8,344
# 5      서울  NaN  18,189  17,925  17,925  18,016  18,098  19,446  18,867
# 6   6대광역시   부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453
# 7     NaN   대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360
# 8     NaN   인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058
# 9     NaN   광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659
# 10    NaN   대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333
# 11    NaN   울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153
# 12    NaN  NaN   8,151   8,355   8,597   8,552   8,585   8,606   8,669
# 13     경기  NaN  10,855  10,855  10,791  10,784  10,876  10,646  10,266
# 14    수도권  NaN  13,083  12,995  13,041  13,069  12,991  13,312  13,064
# ...

# %%
del data1['전월비']
del data1['전년말비']
del data1['전년동월비']
data1
# Out:
#        시도  시군구     12월      1월      2월      3월      4월      5월      6월  \
# 0      전국  NaN   8,059   8,130   8,195   8,204   8,289   8,358   8,344
# 1      서울  NaN  18,189  17,925  17,925  18,016  18,098  19,446  18,867
# 2   6대광역시   부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453
# 3     NaN   대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360
# 4     NaN   인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058
# 5     NaN   광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659
# 6     NaN   대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333
# 7     NaN   울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153
# 8     NaN  NaN   8,151   8,355   8,597   8,552   8,585   8,606   8,669
# 9      경기  NaN  10,855  10,855  10,791  10,784  10,876  10,646  10,266
# 10    수도권  NaN  13,083  12,995  13,041  13,069  12,991  13,312  13,064
# 11     세종  NaN   7,601   7,600   7,532   7,814   7,908   7,934   8,067
# ...

# %%
data1 = data1.drop([8])
data1 = data1.drop([20])
data1
# Out:
#        시도  시군구     12월      1월      2월      3월      4월      5월      6월  \
# 0      전국  NaN   8,059   8,130   8,195   8,204   8,289   8,358   8,344
# 1      서울  NaN  18,189  17,925  17,925  18,016  18,098  19,446  18,867
# 2   6대광역시   부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453
# 3     NaN   대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360
# 4     NaN   인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058
# 5     NaN   광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659
# 6     NaN   대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333
# 7     NaN   울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153
# 9      경기  NaN  10,855  10,855  10,791  10,784  10,876  10,646  10,266
# 10    수도권  NaN  13,083  12,995  13,041  13,069  12,991  13,312  13,064
# 11     세종  NaN   7,601   7,600   7,532   7,814   7,908   7,934   8,067
# 12     지방   강원   6,230   6,230   6,230   6,141   6,373   6,350   6,350
# ...

# %%
del data1['시도']
data1
# Out:
#     시군구     12월      1월      2월      3월      4월      5월      6월      7월  \
# 0   NaN   8,059   8,130   8,195   8,204   8,289   8,358   8,344   8,333
# 1   NaN  18,189  17,925  17,925  18,016  18,098  19,446  18,867  18,742
# 2    부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453   9,457
# 3    대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360   8,360
# 4    인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058   9,974
# 5    광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659   7,612
# 6    대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333   8,333
# 7    울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153   8,153
# 9   NaN  10,855  10,855  10,791  10,784  10,876  10,646  10,266  10,124
# 10  NaN  13,083  12,995  13,041  13,069  12,991  13,312  13,064  12,947
# 11  NaN   7,601   7,600   7,532   7,814   7,908   7,934   8,067   8,067
# 12   강원   6,230   6,230   6,230   6,141   6,373   6,350   6,350   6,268
# ...

# %%
data1.iloc[0, 0] = '전국'
data1.iloc[1, 0] = '서울'
data1.iloc[8, 0] = '경기'
data1.iloc[9, 0] = '수도권'
data1.iloc[10, 0] = '세종'
data1.iloc[11, 0] = '강원'
data1
# Out:
#     시군구     12월      1월      2월      3월      4월      5월      6월      7월  \
# 0    전국   8,059   8,130   8,195   8,204   8,289   8,358   8,344   8,333
# 1    서울  18,189  17,925  17,925  18,016  18,098  19,446  18,867  18,742
# 2    부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453   9,457
# 3    대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360   8,360
# 4    인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058   9,974
# 5    광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659   7,612
# 6    대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333   8,333
# 7    울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153   8,153
# 9    경기  10,855  10,855  10,791  10,784  10,876  10,646  10,266  10,124
# 10  수도권  13,083  12,995  13,041  13,069  12,991  13,312  13,064  12,947
# 11   세종   7,601   7,600   7,532   7,814   7,908   7,934   8,067   8,067
# 12   강원   6,230   6,230   6,230   6,141   6,373   6,350   6,350   6,268
# ...

# %%
data1.reset_index(inplace=False)
data1
# Out:
#     시군구     12월      1월      2월      3월      4월      5월      6월      7월  \
# 0    전국   8,059   8,130   8,195   8,204   8,289   8,358   8,344   8,333
# 1    서울  18,189  17,925  17,925  18,016  18,098  19,446  18,867  18,742
# 2    부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453   9,457
# 3    대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360   8,360
# 4    인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058   9,974
# 5    광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659   7,612
# 6    대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333   8,333
# 7    울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153   8,153
# 9    경기  10,855  10,855  10,791  10,784  10,876  10,646  10,266  10,124
# 10  수도권  13,083  12,995  13,041  13,069  12,991  13,312  13,064  12,947
# 11   세종   7,601   7,600   7,532   7,814   7,908   7,934   8,067   8,067
# 12   강원   6,230   6,230   6,230   6,141   6,373   6,350   6,350   6,268
# ...

# %%
del data1['index']
data1
# Out:
#     시군구     12월      1월      2월      3월      4월      5월      6월      7월  \
# 0    전국   8,059   8,130   8,195   8,204   8,289   8,358   8,344   8,333
# 1    서울  18,189  17,925  17,925  18,016  18,098  19,446  18,867  18,742
# 2    부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453   9,457
# 3    대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360   8,360
# 4    인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058   9,974
# 5    광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659   7,612
# 6    대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333   8,333
# 7    울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153   8,153
# 8    경기  10,855  10,855  10,791  10,784  10,876  10,646  10,266  10,124
# 9   수도권  13,083  12,995  13,041  13,069  12,991  13,312  13,064  12,947
# 10   세종   7,601   7,600   7,532   7,814   7,908   7,934   8,067   8,067
# 11   강원   6,230   6,230   6,230   6,141   6,373   6,350   6,350   6,268
# ...

# %%
data1.columns
# Out:
# Index(['시군구', '12월', '1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월',
#        '10월', '11월', '12월.1', '1월.1', '2월.1', '3월.1', '4월.1', '5월.1', '6월.1',
#        '7월.1', '8월.1', '9월.1'],
#       dtype='object')

# %%
data1.rename(columns={"12월":"201312", "1월":"201401", "2월":"201402", "3월":"201403", "4월":"201404", "5월":"201405", "6월":"201406", "7월":"201407", "8월":"201408", "9월":"201409", "10월":"201410", "11월":"201411"}, inplace=True)

# %%
data1.rename(columns={"12월.1":"201412", "1월.1":"201501", "2월.1":"201502", "3월.1":"201503", "4월.1":"201504", "5월.1":"201505", "6월.1":"201506", "7월.1":"201507", "8월.1":"201508", "9월.1":"201509"}, inplace=True)
data1
# Out:
#     시군구  201312  201401  201402  201403  201404  201405  201406  201407  \
# 0    전국   8,059   8,130   8,195   8,204   8,289   8,358   8,344   8,333
# 1    서울  18,189  17,925  17,925  18,016  18,098  19,446  18,867  18,742
# 2    부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453   9,457
# 3    대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360   8,360
# 4    인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058   9,974
# 5    광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659   7,612
# 6    대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333   8,333
# 7    울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153   8,153
# 9    경기  10,855  10,855  10,791  10,784  10,876  10,646  10,266  10,124
# 10  수도권  13,083  12,995  13,041  13,069  12,991  13,312  13,064  12,947
# 11   세종   7,601   7,600   7,532   7,814   7,908   7,934   8,067   8,067
# 12   강원   6,230   6,230   6,230   6,141   6,373   6,350   6,350   6,268
# ...

# %%
data1 = data1.drop([0])
data1
# Out:
#     시군구  201312  201401  201402  201403  201404  201405  201406  201407  \
# 1    서울  18,189  17,925  17,925  18,016  18,098  19,446  18,867  18,742
# 2    부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453   9,457
# 3    대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360   8,360
# 4    인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058   9,974
# 5    광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659   7,612
# 6    대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333   8,333
# 7    울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153   8,153
# 9    경기  10,855  10,855  10,791  10,784  10,876  10,646  10,266  10,124
# 10  수도권  13,083  12,995  13,041  13,069  12,991  13,312  13,064  12,947
# 11   세종   7,601   7,600   7,532   7,814   7,908   7,934   8,067   8,067
# 12   강원   6,230   6,230   6,230   6,141   6,373   6,350   6,350   6,268
# 13   충북   6,589   6,589   6,611   6,625   6,678   6,598   6,587   6,586
# ...

# %%
# Out:
#        연도   월 분양가격(㎡) 시군구  201312  201401  201402  201403  201404  201405  \
# 0    2015  10    5841  서울  18,189  17,925  17,925  18,016  18,098  19,446
# 1    2015  10    3163  인천  10,204  10,204  10,408  10,408  10,000   9,844
# 2    2015  10    3138  경기  10,855  10,855  10,791  10,784  10,876  10,646
# 3    2015  10    3112  부산   8,111   8,111   9,078   8,965   9,402   9,501
# 4    2015  10    2682  대구   8,080   8,080   8,077   8,101   8,267   8,274
# ..    ...  ..     ...  ..     ...     ...     ...     ...     ...     ...
# 573  2018   7    2333  전북   6,282   6,281   5,946   5,966   6,277   6,306
# 574  2018   7    2357  전남   5,678   5,678   5,678   5,696   5,736   5,656
# 575  2018   7    2674  경북   6,168   6,168   6,234   6,317   6,412   6,409
# 576  2018   7    2696  경남   6,473   6,485   6,502   6,610   6,599   6,610
# 577  2018   7    3334  제주   7,674   7,900   7,900   7,900   7,900   7,900
#
#      ...  201412  201501  201502  201503  201504  201505  201506  201507  \
# ...

# %%
total.index = total['시군구']
total
# Out:
#        연도   월 분양가격(㎡) 시군구  201312  201401  201402  201403  201404  201405  \
# 시군구
# 서울   2015  10    5841  서울  18,189  17,925  17,925  18,016  18,098  19,446
# 인천   2015  10    3163  인천  10,204  10,204  10,408  10,408  10,000   9,844
# 경기   2015  10    3138  경기  10,855  10,855  10,791  10,784  10,876  10,646
# 부산   2015  10    3112  부산   8,111   8,111   9,078   8,965   9,402   9,501
# 대구   2015  10    2682  대구   8,080   8,080   8,077   8,101   8,267   8,274
# ..    ...  ..     ...  ..     ...     ...     ...     ...     ...     ...
# 전북   2018   7    2333  전북   6,282   6,281   5,946   5,966   6,277   6,306
# 전남   2018   7    2357  전남   5,678   5,678   5,678   5,696   5,736   5,656
# 경북   2018   7    2674  경북   6,168   6,168   6,234   6,317   6,412   6,409
# 경남   2018   7    2696  경남   6,473   6,485   6,502   6,610   6,599   6,610
# 제주   2018   7    3334  제주   7,674   7,900   7,900   7,900   7,900   7,900
#
# ...

# %%
data2 = pd.read_csv('./dataset/aptPriceDataSet/avg18.07.csv')
data2
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 0     서울                 전체  2015  10    5841
# 1     서울         전용면적 60㎡이하  2015  10    5652
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4     서울        전용면적 102㎡초과  2015  10    5879
# ...   ..                ...   ...  ..     ...
# 2885  제주                 전체  2018   7    3334
# 2886  제주         전용면적 60㎡이하  2018   7     NaN
# 2887  제주   전용면적 60㎡초과 85㎡이하  2018   7    3356
# 2888  제주  전용면적 85㎡초과 102㎡이하  2018   7    3226
# 2889  제주        전용면적 102㎡초과  2018   7    2990
#
# [2890 rows x 5 columns]

# %%
data3 = []

def get_row():
    for v in data2.index:
        if data2.iloc[v, 1] == '전체':
            data3.append(str(data2.iloc[v, 0:5].values))
            
get_row()
print(data3)
# Out:
# ["['서울' '전체' 2015 10 '5841']", "['인천' '전체' 2015 10 '3163']", "['경기' '전체' 2015 10 '3138']", "['부산' '전체' 2015 10 '3112']", "['대구' '전체' 2015 10 '2682']", "['광주' '전체' 2015 10 '2420']", "['대전' '전체' 2015 10 '2454']", "['울산' '전체' 2015 10 '3053']", "['세종' '전체' 2015 10 '2642']", "['강원' '전체' 2015 10 '2167']", "['충북' '전체' 2015 10 '2032']", "['충남' '전체' 2015 10 '2099']", "['전북' '전체' 2015 10 '2054']", "['전남' '전체' 2015 10 '1925']", "['경북' '전체' 2015 10 '2148']", "['경남' '전체' 2015 10 '2291']", "['제주' '전체' 2015 10 '2232']", "['서울' '전체' 2015 11 '6050']", "['인천' '전체' 2015 11 '3184']", "['경기' '전체' 2015 11 '3098']", "['부산' '전체' 2015 11 '3131']", "['대구' '전체' 2015 11 '2749']", "['광주' '전체' 2015 11 '2424']", "['대전' '전체' 2015 11 '2454']", "['울산' '전체' 2015 11 '3043']", "['세종' '전체' 2015 11 '2648']", "['강원' '전체' 2015 11 '2171']", "['충북' '전체' 2015 11 '2004']", "['충남' '전체' 2015 11 '2100']", "['전북' '전체' 2015 11 '2057']", "['전남' '전체' 2015 11 '1909']", "['경북' '전체' 2015 11 '2190']", "['경남' '전체' 2015 11 '2298']", "['제주' 
# ...

# %%
boolean = data2['규모구분'] == '전체'
boolean
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2885     True
# 2886    False
# 2887    False
# 2888    False
# 2889    False
# Name: 규모구분, Length: 2890, dtype: bool

# %%
df = data2[boolean]
df
# Out:
#      지역명 규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 0     서울   전체  2015  10    5841  5841.0  19275.3
# 5     인천   전체  2015  10    3163  3163.0  10437.9
# 10    경기   전체  2015  10    3138  3138.0  10355.4
# 15    부산   전체  2015  10    3112  3112.0  10269.6
# 20    대구   전체  2015  10    2682  2682.0   8850.6
# ...   ..  ...   ...  ..     ...     ...      ...
# 2865  전북   전체  2018   7    2333  2333.0   7698.9
# 2870  전남   전체  2018   7    2357  2357.0   7778.1
# 2875  경북   전체  2018   7    2674  2674.0   8824.2
# 2880  경남   전체  2018   7    2696  2696.0   8896.8
# 2885  제주   전체  2018   7    3334  3334.0  11002.2
#
# [578 rows x 7 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#      index 지역명 규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 0        0  서울   전체  2015  10    5841  5841.0  19275.3
# 1        5  인천   전체  2015  10    3163  3163.0  10437.9
# 2       10  경기   전체  2015  10    3138  3138.0  10355.4
# 3       15  부산   전체  2015  10    3112  3112.0  10269.6
# 4       20  대구   전체  2015  10    2682  2682.0   8850.6
# ..     ...  ..  ...   ...  ..     ...     ...      ...
# 573   2865  전북   전체  2018   7    2333  2333.0   7698.9
# 574   2870  전남   전체  2018   7    2357  2357.0   7778.1
# 575   2875  경북   전체  2018   7    2674  2674.0   8824.2
# 576   2880  경남   전체  2018   7    2696  2696.0   8896.8
# 577   2885  제주   전체  2018   7    3334  3334.0  11002.2
#
# [578 rows x 8 columns]

# %%
del df['index']
del df['분양가격']
del df['분양가격(㎡)']
df
# Out:
#     지역명 규모구분    연도   월   평당분양가격
# 0    서울   전체  2015  10  19275.3
# 1    인천   전체  2015  10  10437.9
# 2    경기   전체  2015  10  10355.4
# 3    부산   전체  2015  10  10269.6
# 4    대구   전체  2015  10   8850.6
# ..   ..  ...   ...  ..      ...
# 573  전북   전체  2018   7   7698.9
# 574  전남   전체  2018   7   7778.1
# 575  경북   전체  2018   7   8824.2
# 576  경남   전체  2018   7   8896.8
# 577  제주   전체  2018   7  11002.2
#
# [578 rows x 5 columns]

# %%
del df['규모구분']
df
# Out:
#     지역명    연도   월   평당분양가격
# 0    서울  2015  10  19275.3
# 1    인천  2015  10  10437.9
# 2    경기  2015  10  10355.4
# 3    부산  2015  10  10269.6
# 4    대구  2015  10   8850.6
# ..   ..   ...  ..      ...
# 573  전북  2018   7   7698.9
# 574  전남  2018   7   7778.1
# 575  경북  2018   7   8824.2
# 576  경남  2018   7   8896.8
# 577  제주  2018   7  11002.2
#
# [578 rows x 4 columns]

# %%
total = pd.merge(left=df,
                right=data1,
                how='left',
                left_on='지역명',
                right_on='시군구')

total
# Out:
#     지역명    연도   월   평당분양가격 시군구  201312  201401  201402  201403  201404  ...  \
# 0    서울  2015  10  19275.3  서울  18,189  17,925  17,925  18,016  18,098  ...
# 1    인천  2015  10  10437.9  인천  10,204  10,204  10,408  10,408  10,000  ...
# 2    경기  2015  10  10355.4  경기  10,855  10,855  10,791  10,784  10,876  ...
# 3    부산  2015  10  10269.6  부산   8,111   8,111   9,078   8,965   9,402  ...
# 4    대구  2015  10   8850.6  대구   8,080   8,080   8,077   8,101   8,267  ...
# ..   ..   ...  ..      ...  ..     ...     ...     ...     ...     ...  ...
# 573  전북  2018   7   7698.9  전북   6,282   6,281   5,946   5,966   6,277  ...
# 574  전남  2018   7   7778.1  전남   5,678   5,678   5,678   5,696   5,736  ...
# 575  경북  2018   7   8824.2  경북   6,168   6,168   6,234   6,317   6,412  ...
# 576  경남  2018   7   8896.8  경남   6,473   6,485   6,502   6,610   6,599  ...
# 577  제주  2018   7  11002.2  제주   7,674   7,900   7,900   7,900   7,900  ...
#
# ...

# %%
data2.iloc[0, 1]
# Out:
# '전체'

# %%
data2.index
# Out:
# RangeIndex(start=0, stop=2890, step=1)

# %%
data2.iloc[0]
# Out:
# 지역명          서울
# 규모구분         전체
# 연도         2015
# 월            10
# 분양가격(㎡)    5841
# Name: 0, dtype: object

# %%
data2_price = data2.iloc[:, 4]
data2['분양가격'] = pd.to_numeric(data2_price, errors='coerce')
data2.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)    분양가격
# 0  서울                 전체  2015  10    5841  5841.0
# 1  서울         전용면적 60㎡이하  2015  10    5652  5652.0
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882  5882.0
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721  5721.0
# 4  서울        전용면적 102㎡초과  2015  10    5879  5879.0

# %%
data2['평당분양가격'] = data2['분양가격'] * 3.3
data2
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 0     서울                 전체  2015  10    5841  5841.0  19275.3
# 1     서울         전용면적 60㎡이하  2015  10    5652  5652.0  18651.6
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882  5882.0  19410.6
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721  5721.0  18879.3
# 4     서울        전용면적 102㎡초과  2015  10    5879  5879.0  19400.7
# ...   ..                ...   ...  ..     ...     ...      ...
# 2885  제주                 전체  2018   7    3334  3334.0  11002.2
# 2886  제주         전용면적 60㎡이하  2018   7     NaN     NaN      NaN
# 2887  제주   전용면적 60㎡초과 85㎡이하  2018   7    3356  3356.0  11074.8
# 2888  제주  전용면적 85㎡초과 102㎡이하  2018   7    3226  3226.0  10645.8
# 2889  제주        전용면적 102㎡초과  2018   7    2990  2990.0   9867.0
#
# [2890 rows x 7 columns]

# %%
data2 = data2.fillna(0)
data2
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 0     서울                 전체  2015  10    5841  5841.0  19275.3
# 1     서울         전용면적 60㎡이하  2015  10    5652  5652.0  18651.6
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882  5882.0  19410.6
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721  5721.0  18879.3
# 4     서울        전용면적 102㎡초과  2015  10    5879  5879.0  19400.7
# ...   ..                ...   ...  ..     ...     ...      ...
# 2885  제주                 전체  2018   7    3334  3334.0  11002.2
# 2886  제주         전용면적 60㎡이하  2018   7       0     0.0      0.0
# 2887  제주   전용면적 60㎡초과 85㎡이하  2018   7    3356  3356.0  11074.8
# 2888  제주  전용면적 85㎡초과 102㎡이하  2018   7    3226  3226.0  10645.8
# 2889  제주        전용면적 102㎡초과  2018   7    2990  2990.0   9867.0
#
# [2890 rows x 7 columns]

# %%
td = data1.transpose()
td
# Out:
#             1      2      3       4      5      6      7       9       10  \
# 시군구         서울     부산     대구      인천     광주     대전     울산      경기     수도권
# 201312  18,189  8,111  8,080  10,204  6,098  8,321  8,090  10,855  13,083
# 201401  17,925  8,111  8,080  10,204  7,326  8,321  8,090  10,855  12,995
# 201402  17,925  9,078  8,077  10,408  7,611  8,321  8,090  10,791  13,041
# 201403  18,016  8,965  8,101  10,408  7,346  8,341  8,153  10,784  13,069
# 201404  18,098  9,402  8,267  10,000  7,346  8,341  8,153  10,876  12,991
# 201405  19,446  9,501  8,274   9,844  7,523  8,341  8,153  10,646  13,312
# 201406  18,867  9,453  8,360  10,058  7,659  8,333  8,153  10,266  13,064
# 201407  18,742  9,457  8,360   9,974  7,612  8,333  8,153  10,124  12,947
# 201408  19,274  9,411  8,370   9,973  7,622  8,333  8,493  10,134  13,127
# 201409  19,404  9,258  8,449   9,973  7,802  8,048  8,493  10,501  13,293
# 201410  19,759  9,110  8,403  10,016  7,707  8,038  8,627  10,397  13,391
# ...

# %%
td.columns = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '수도권', '세종', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주']
td
# Out:
#             서울     부산     대구      인천     광주     대전     울산      경기     수도권  \
# 201312  18,189  8,111  8,080  10,204  6,098  8,321  8,090  10,855  13,083
# 201401  17,925  8,111  8,080  10,204  7,326  8,321  8,090  10,855  12,995
# 201402  17,925  9,078  8,077  10,408  7,611  8,321  8,090  10,791  13,041
# 201403  18,016  8,965  8,101  10,408  7,346  8,341  8,153  10,784  13,069
# 201404  18,098  9,402  8,267  10,000  7,346  8,341  8,153  10,876  12,991
# 201405  19,446  9,501  8,274   9,844  7,523  8,341  8,153  10,646  13,312
# 201406  18,867  9,453  8,360  10,058  7,659  8,333  8,153  10,266  13,064
# 201407  18,742  9,457  8,360   9,974  7,612  8,333  8,153  10,124  12,947
# 201408  19,274  9,411  8,370   9,973  7,622  8,333  8,493  10,134  13,127
# 201409  19,404  9,258  8,449   9,973  7,802  8,048  8,493  10,501  13,293
# 201410  19,759  9,110  8,403  10,016  7,707  8,038  8,627  10,397  13,391
# 201411  20,242  9,208  8,439  10,020  7,752  8,067  8,891  10,356  13,539
# ...

# %%
td = td.drop(['시군구'])
td
# Out:
#             1      2      3       4      5      6      7       9       10  \
# 201312  18,189  8,111  8,080  10,204  6,098  8,321  8,090  10,855  13,083
# 201401  17,925  8,111  8,080  10,204  7,326  8,321  8,090  10,855  12,995
# 201402  17,925  9,078  8,077  10,408  7,611  8,321  8,090  10,791  13,041
# 201403  18,016  8,965  8,101  10,408  7,346  8,341  8,153  10,784  13,069
# 201404  18,098  9,402  8,267  10,000  7,346  8,341  8,153  10,876  12,991
# 201405  19,446  9,501  8,274   9,844  7,523  8,341  8,153  10,646  13,312
# 201406  18,867  9,453  8,360  10,058  7,659  8,333  8,153  10,266  13,064
# 201407  18,742  9,457  8,360   9,974  7,612  8,333  8,153  10,124  12,947
# 201408  19,274  9,411  8,370   9,973  7,622  8,333  8,493  10,134  13,127
# 201409  19,404  9,258  8,449   9,973  7,802  8,048  8,493  10,501  13,293
# 201410  19,759  9,110  8,403  10,016  7,707  8,038  8,627  10,397  13,391
# 201411  20,242  9,208  8,439  10,020  7,752  8,067  8,891  10,356  13,539
# ...

# %%
td['서울'] = td['서울'].str.replace(',','')
td['서울'] = pd.to_numeric(td['서울'], errors='coerce')
td
# Out:
#            서울     부산     대구      인천     광주     대전     울산      경기     수도권  \
# 201312  18189  8,111  8,080  10,204  6,098  8,321  8,090  10,855  13,083
# 201401  17925  8,111  8,080  10,204  7,326  8,321  8,090  10,855  12,995
# 201402  17925  9,078  8,077  10,408  7,611  8,321  8,090  10,791  13,041
# 201403  18016  8,965  8,101  10,408  7,346  8,341  8,153  10,784  13,069
# 201404  18098  9,402  8,267  10,000  7,346  8,341  8,153  10,876  12,991
# 201405  19446  9,501  8,274   9,844  7,523  8,341  8,153  10,646  13,312
# 201406  18867  9,453  8,360  10,058  7,659  8,333  8,153  10,266  13,064
# 201407  18742  9,457  8,360   9,974  7,612  8,333  8,153  10,124  12,947
# 201408  19274  9,411  8,370   9,973  7,622  8,333  8,493  10,134  13,127
# 201409  19404  9,258  8,449   9,973  7,802  8,048  8,493  10,501  13,293
# 201410  19759  9,110  8,403  10,016  7,707  8,038  8,627  10,397  13,391
# 201411  20242  9,208  8,439  10,020  7,752  8,067  8,891  10,356  13,539
# ...

# %%
td['부산'] = td['부산'].str.replace(',','')
td['부산'] = pd.to_numeric(td['부산'], errors='coerce')

td['대구'] = td['대구'].str.replace(',','')
td['대구'] = pd.to_numeric(td['대구'], errors='coerce')

td['인천'] = td['인천'].str.replace(',','')
td['인천'] = pd.to_numeric(td['인천'], errors='coerce')

td['광주'] = td['광주'].str.replace(',','')
td['광주'] = pd.to_numeric(td['광주'], errors='coerce')

td['대전'] = td['대전'].str.replace(',','')
td['대전'] = pd.to_numeric(td['대전'], errors='coerce')

td['울산'] = td['울산'].str.replace(',','')
td['울산'] = pd.to_numeric(td['울산'], errors='coerce')

td['경기'] = td['경기'].str.replace(',','')
td['경기'] = pd.to_numeric(td['경기'], errors='coerce')

td['수도권'] = td['수도권'].str.replace(',','')
td['수도권'] = pd.to_numeric(td['수도권'], errors='coerce')

td['세종'] = td['세종'].str.replace(',','')
td['세종'] = pd.to_numeric(td['세종'], errors='coerce')

td['강원'] = td['강원'].str.replace(',','')
td['강원'] = pd.to_numeric(td['강원'], errors='coerce')

td['충북'] = td['충북'].str.replace(',','')
td['충북'] = pd.to_numeric(td['충북'], errors='coerce')

td['충남'] = td['충남'].str.replace(',','')
td['충남'] = pd.to_numeric(td['충남'], errors='coerce')

td['전북'] = td['전북'].str.replace(',','')
td['전북'] = pd.to_numeric(td['전북'], errors='coerce')

td['전남'] = td['전남'].str.replace(',','')
td['전남'] = pd.to_numeric(td['전남'], errors='coerce')

td['경북'] = td['경북'].str.replace(',','')
td['경북'] = pd.to_numeric(td['경북'], errors='coerce')

td['경남'] = td['경남'].str.replace(',','')
td['경남'] = pd.to_numeric(td['경남'], errors='coerce')

td['제주'] = td['제주'].str.replace(',','')
td['제주'] = pd.to_numeric(td['제주'], errors='coerce')

td
# Out:
#            서울    부산    대구     인천    광주    대전    울산     경기    수도권    세종    강원  \
# 201312  18189  8111  8080  10204  6098  8321  8090  10855  13083  7601  6230
# 201401  17925  8111  8080  10204  7326  8321  8090  10855  12995  7600  6230
# 201402  17925  9078  8077  10408  7611  8321  8090  10791  13041  7532  6230
# 201403  18016  8965  8101  10408  7346  8341  8153  10784  13069  7814  6141
# 201404  18098  9402  8267  10000  7346  8341  8153  10876  12991  7908  6373
# 201405  19446  9501  8274   9844  7523  8341  8153  10646  13312  7934  6350
# 201406  18867  9453  8360  10058  7659  8333  8153  10266  13064  8067  6350
# 201407  18742  9457  8360   9974  7612  8333  8153  10124  12947  8067  6268
# 201408  19274  9411  8370   9973  7622  8333  8493  10134  13127  8141  6268
# 201409  19404  9258  8449   9973  7802  8048  8493  10501  13293  8282  6419
# 201410  19759  9110  8403  10016  7707  8038  8627  10397  13391  8527  6631
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# https://teddylee777.github.io/visualization/matplotlib-%EC%8B%9C%EA%B0%81%ED%99%94-%ED%95%9C%EA%B8%80%ED%8F%B0%ED%8A%B8%EC%A0%81%EC%9A%A9
# https://lsh-story.tistory.com/79

# jupyter notebook 내 그래프를 바로 그리기 위한 설정
# %matplotlib inline

# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False

# %%
# figsize 를 전역으로 설정
plt.rcParams['figure.figsize'] = (13, 8)

plt.rcParams['font.family'] = 'Malgun Gothic'
td.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.font_manager as fm

# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'cmex10',
#  'STIXGeneral',
#  'cmtt10',
#  'cmb10',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'STIXNonUnicode',
#  'cmmi10',
#  'DejaVu Sans Display',
#  'cmr10',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'cmsy10',
#  'cmss10',
#  'STIXSizeThreeSym',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'Yu Gothic',
#  'Lucida Bright',
#  'Franklin Gothic Medium Cond',
#  'Rockwell Extra Bold',
#  'Chiller',
#  'Arial',
#  'Perpetua Titling MT',
#  'Century Schoolbook',
#  'Segoe UI',
#  'Verdana',
#  'Constantia',
#  'Lucida Fax',
#  'New Gulim',
# ...
