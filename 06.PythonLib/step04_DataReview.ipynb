# %% [markdown]
# 1. Pandas 이용해서 데이터 다양하게 처리
# 2. 제출 시간 5시 30분

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('dataset/20201231.csv', encoding='euc-kr')
df
# Out:
#         구분 시설종류     공종명        객체       위치   작업프로세스                원인  물적피해  \
# 0   201801   토목  콘크리트공사        벽체       인접     철근조립          전도방지 미조치   넘어짐
# 1   201802   건축    리모델링       슬래브       하부       보강           구조검토 미흡   무너짐
# 2   201803   건축    마감공사    외벽작업발판       고소       마감           앵커 시공불량   무너짐
# 3   201804   건축    철골공사    이동식크레인       인접       양중           빠른 선회속도   넘어짐
# 4   201805   건축    설비공사  이동식 가설구대       고소   천장설비설치     가설구대 이동속도 불균형   무너짐
# 5   201806   토목  콘크리트공사       브라켓       하부  PC부재 조립            철근 미시공    파괴
# 6   201807   건축    설비공사       단열재       인접       용접              용접불티    화재
# 7   201808   토목    유지보수      점검계단       고소       이동           앵커 시공불량   무너짐
# 8   201809   토목    옹벽공사      성토사면       인접       다짐            경사도 불량   무너짐
# 9   201810   건축    해체공사       구조물     철거방향       철거           횡하중(철거)   넘어짐
# 10  201811   건축    가설공사       거푸집       인접     비계설치              임의해체   넘어짐
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      56 non-null     int64
#  1   시설종류    56 non-null     object
#  2   공종명     56 non-null     object
#  3   객체      56 non-null     object
#  4   위치      56 non-null     object
#  5   작업프로세스  56 non-null     object
#  6   원인      56 non-null     object
#  7   물적피해    56 non-null     object
#  8   인적피해    56 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 4.1+ KB

# %%
df.columns
# Out:
# Index(['구분', '시설종류', '공종명', '객체', '위치', '작업프로세스', '원인', '물적피해', '인적피해'], dtype='object')

# %%
df.head()
# Out:
#        구분 시설종류     공종명        객체  위치  작업프로세스             원인 물적피해 인적피해
# 0  201801   토목  콘크리트공사        벽체  인접    철근조립       전도방지 미조치  넘어짐   깔림
# 1  201802   건축    리모델링       슬래브  하부      보강        구조검토 미흡  무너짐   깔림
# 2  201803   건축    마감공사    외벽작업발판  고소      마감        앵커 시공불량  무너짐  떨어짐
# 3  201804   건축    철골공사    이동식크레인  인접      양중        빠른 선회속도  넘어짐   없음
# 4  201805   건축    설비공사  이동식 가설구대  고소  천장설비설치  가설구대 이동속도 불균형  무너짐  떨어짐

# %%
df.tail()
# Out:
#         구분 시설종류     공종명      객체  위치 작업프로세스          원인 물적피해 인적피해
# 51  202009   건축  콘크리트공사  데크플레이트  상부     타설        용접불량  무너짐  떨어짐
# 52  202010   건축  콘크리트공사  데크플레이트  하부     운반        적재불량   낙하   맞음
# 53  202011   건축  콘크리트공사     가시설  상부     타설     구조검토 미흡  무너짐  떨어짐
# 54  202012   토목    도로공사   크레인 붐  하부     해체    안전조치 부적정   없음   깔림
# 55  202013   토목    터널공사   터널천단부  내부   굴착작업  천단부 암반 불안정   붕락   깔림

# %%
df.loc[0:5, ['구분', '원인', '물적피해', '인적피해']]
# Out:
#        구분             원인 물적피해 인적피해
# 0  201801       전도방지 미조치  넘어짐   깔림
# 1  201802        구조검토 미흡  무너짐   깔림
# 2  201803        앵커 시공불량  무너짐  떨어짐
# 3  201804        빠른 선회속도  넘어짐   없음
# 4  201805  가설구대 이동속도 불균형  무너짐  떨어짐
# 5  201806         철근 미시공   파괴   깔림

# %%
h = pd.DataFrame({'count': df.groupby('인적피해').size()}).reset_index()
h
# Out:
#   인적피해  count
# 0   깔림     16
# 1  넘어짐      1
# 2  떨어짐     17
# 3   맞음      4
# 4  부딪힘      1
# 5   없음      9
# 6   익사      1
# 7   질식      7

# %%
for i in df['구분']:
    print(str(i)[0:4])
    
def get_year(i):
    return str(i)[0:4]

df['발생연도'] = df['구분'].apply(get_year)
df
# Out:
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
#         구분 시설종류     공종명        객체       위치   작업프로세스                원인  물적피해  \
# 0   201801   토목  콘크리트공사        벽체       인접     철근조립          전도방지 미조치   넘어짐
# 1   201802   건축    리모델링       슬래브       하부       보강           구조검토 미흡   무너짐
# 2   201803   건축    마감공사    외벽작업발판       고소       마감           앵커 시공불량   무너짐
# 3   201804   건축    철골공사    이동식크레인       인접       양중           빠른 선회속도   넘어짐
# 4   201805   건축    설비공사  이동식 가설구대       고소   천장설비설치     가설구대 이동속도 불균형   무너짐
# 5   201806   토목  콘크리트공사       브라켓       하부  PC부재 조립            철근 미시공    파괴
# ...

# %%
df
# Out:
#         구분 시설종류     공종명        객체       위치   작업프로세스                원인  물적피해  \
# 0   201801   토목  콘크리트공사        벽체       인접     철근조립          전도방지 미조치   넘어짐
# 1   201802   건축    리모델링       슬래브       하부       보강           구조검토 미흡   무너짐
# 2   201803   건축    마감공사    외벽작업발판       고소       마감           앵커 시공불량   무너짐
# 3   201804   건축    철골공사    이동식크레인       인접       양중           빠른 선회속도   넘어짐
# 4   201805   건축    설비공사  이동식 가설구대       고소   천장설비설치     가설구대 이동속도 불균형   무너짐
# 5   201806   토목  콘크리트공사       브라켓       하부  PC부재 조립            철근 미시공    파괴
# 6   201807   건축    설비공사       단열재       인접       용접              용접불티    화재
# 7   201808   토목    유지보수      점검계단       고소       이동           앵커 시공불량   무너짐
# 8   201809   토목    옹벽공사      성토사면       인접       다짐            경사도 불량   무너짐
# 9   201810   건축    해체공사       구조물     철거방향       철거           횡하중(철거)   넘어짐
# 10  201811   건축    가설공사       거푸집       인접     비계설치              임의해체   넘어짐
# ...

# %%
y = pd.DataFrame({'count': df.groupby('발생연도').size()}).reset_index()
y
# Out:
#    발생연도  count
# 0  2018     18
# 1  2019     25
# 2  2020     13
